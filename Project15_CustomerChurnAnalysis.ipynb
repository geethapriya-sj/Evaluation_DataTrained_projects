# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Customer_Dataset.csv')

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.shape
# Out:
# (3333, 21)

# %%
df.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %%
sns.countplot(x='churn',data=df)

# %% [markdown]
# #data is bery imbalanced ,as True is very much less than false

# %%
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
plt.figure(figsize=(50,10))
sns.barplot(x='state',y='churn',data=df,)

# %%
df.groupby(["state", "churn"]).size().unstack().plot()

# %%
plt.figure(figsize=(100,50))
df.groupby(["state", "churn"]).size().unstack().plot(kind='bar',stacked=True)

# %%
df.groupby(["international plan", "churn"]).size().unstack().plot(kind='bar')

# %%
df.groupby(["voice mail plan", "churn"]).size().unstack().plot(kind='bar')

# %%
df.groupby(["area code", "churn"]).size().unstack().plot(kind='bar')

# %%
df['area code'].unique()
# Out:
# array([415, 408, 510], dtype=int64)

# %%
df.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
df['state'].unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
# Discreet value integer encoder
label_encoder = LabelEncoder()

# %%
# State is string and we want discreet integer values
df['state'] = label_encoder.fit_transform(df['state'])
df['international plan'] = label_encoder.fit_transform(df['international plan'])
df['voice mail plan'] = label_encoder.fit_transform(df['voice mail plan'])

# %%
df.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
df.drop(columns=['phone number','account length'])
# dont think these columns play imortant role to determine churn
# Out:
#       state  area code  international plan  voice mail plan  \
# 0        16        415                   0                1
# 1        35        415                   0                1
# 2        31        415                   0                0
# 3        35        408                   1                0
# 4        36        415                   1                0
# ...     ...        ...                 ...              ...
# 3328      3        415                   0                1
# 3329     49        415                   0                0
# 3330     39        510                   0                0
# 3331      6        510                   1                0
# 3332     42        415                   0                1
#
#       number vmail messages  total day minutes  total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# ...

# %%
df.drop(columns=[])
# Out:
#       state  account length  area code phone number  international plan  \
# 0        16             128        415     382-4657                   0
# 1        35             107        415     371-7191                   0
# 2        31             137        415     358-1921                   0
# 3        35              84        408     375-9999                   1
# 4        36              75        415     330-6626                   1
# ...     ...             ...        ...          ...                 ...
# 3328      3             192        415     414-4276                   0
# 3329     49              68        415     370-3271                   0
# 3330     39              28        510     328-8230                   0
# 3331      6             184        510     364-6381                   1
# 3332     42              74        415     400-4344                   0
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
plt.figure(figsize=(30,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')

# %% [markdown]
# #Voice mail plan and voice mail messages are highly correlate

# %%
df[(df['number vmail messages'] == 0) & (df['voice mail plan'] == 1)]
# Out:
# Empty DataFrame
# Columns: [state, account length, area code, phone number, international plan, voice mail plan, number vmail messages, total day minutes, total day calls, total day charge, total eve minutes, total eve calls, total eve charge, total night minutes, total night calls, total night charge, total intl minutes, total intl calls, total intl charge, customer service calls, churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.drop(columns=['number vmail messages'],inplace=True)
#voice mail plan and vmail messages are highly correlated, so dropping one

# %%
df.drop(columns=['phone number'],inplace=True)
#voice mail plan and vmail messages are highly correlated, so dropping one

# %%
df.head()
# Out:
#    state  account length  area code  international plan  voice mail plan  \
# 0     16             128        415                   0                1
# 1     35             107        415                   0                1
# 2     31             137        415                   0                0
# 3     35              84        408                   1                0
# 4     36              75        415                   1                0
#
#    total day minutes  total day calls  total day charge  total eve minutes  \
# 0              265.1              110             45.07              197.4
# 1              161.6              123             27.47              195.5
# 2              243.4              114             41.38              121.2
# 3              299.4               71             50.90               61.9
# 4              166.7              113             28.34              148.3
#
# ...

# %%
df2 = df.copy()

# %%
churn_true = df2[df2['churn']==True]
churn_false = df2[df2['churn']==False]
plt.figure(figsize=(12,7))
ax=sns.kdeplot(churn_true['total day charge'],color='r',label='chrun-True',shade=True)
ax=sns.kdeplot(churn_false['total day charge'],color='g',label='chrun-false',shade=True)
ax.set(xlabel='Average total day charge',ylabel='Frequency')
plt.title('Average total day charge for left and retain')
# Out:
# Text(0.5, 1.0, 'Average total day charge for left and retain')

# %%
churn_true = df2[df2['churn']==True]
churn_false = df2[df2['churn']==False]
plt.figure(figsize=(12,7))
ax=sns.kdeplot(churn_true['total eve charge'],color='r',label='chrun-True',shade=True)
ax=sns.kdeplot(churn_false['total eve charge'],color='g',label='chrun-false',shade=True)
ax.set(xlabel='Average total eve  charge',ylabel='Frequency')
plt.title('Average total eve  charge for left and retain')
# Out:
# Text(0.5, 1.0, 'Average total eve  charge for left and retain')

# %%
churn_true = df2[df2['churn']==True]
churn_false = df2[df2['churn']==False]
plt.figure(figsize=(12,7))
ax=sns.kdeplot(churn_true['total night charge'],color='r',label='chrun-True',shade=True)
ax=sns.kdeplot(churn_false['total night charge'],color='g',label='chrun-false',shade=True)
ax.set(xlabel='Average total night   charge',ylabel='Frequency')
plt.title('Average total night   charge for left and retain')
# Out:
# Text(0.5, 1.0, 'Average total night   charge for left and retain')

# %%
df2['Total_charge'] = df2['total day charge'] + df2['total eve charge'] + df2['total night charge'] + df2['total intl charge']

# %%
df2['Total_calls'] = df2['total day calls'] + df2['total eve calls'] + df2['total night calls'] + df2['total intl calls']

# %%
df2['Total_minutes'] = df2['total day minutes'] + df2['total eve minutes'] + df2['total night minutes'] + df2['total intl minutes']

# %%
churn_true = df2[df2['churn']==True]
churn_false = df2[df2['churn']==False]
plt.figure(figsize=(12,7))
ax=sns.kdeplot(churn_true['Total_charge'],color='r',label='chrun-True',shade=True)
ax=sns.kdeplot(churn_false['Total_charge'],color='g',label='chrun-false',shade=True)
ax.set(xlabel='Average total charge',ylabel='Frequency')
plt.title('Average total charge for left and retain')
# Out:
# Text(0.5, 1.0, 'Average total charge for left and retain')

# %%
churn_true = df[df['churn']==True]
churn_false = df[df['churn']==False]
plt.figure(figsize=(12,7))
ax=sns.kdeplot(churn_true['Total_minutes'],color='r',label='chrun-True',shade=True)
ax=sns.kdeplot(churn_false['Total_minutes'],color='g',label='chrun-false',shade=True)
ax.set(xlabel='Average total minutes',ylabel='Frequency')
plt.title('Average total minutes for left and retain')
# Out:
# Text(0.5, 1.0, 'Average total minutes for left and retain')

# %%
churn_true = df2[df2['churn']==True]
churn_false = df2[df2['churn']==False]
plt.figure(figsize=(12,7))
ax=sns.kdeplot(churn_true['Total_calls'],color='r',label='chrun-True',shade=True)
ax=sns.kdeplot(churn_false['Total_calls'],color='g',label='chrun-false',shade=True)
ax.set(xlabel='Average total calls',ylabel='Frequency')
plt.title('Average total calls for left and retain')
# Out:
# Text(0.5, 1.0, 'Average total calls for left and retain')

# %%
X=df.drop(columns=['churn'])
y=df['churn']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score
from imblearn.over_sampling import SMOTE
def max_score(model,X,y):
    max_score= 0
    cross_max_score = 0
    for r in range(42,100):
        cross_max_score = cross_val_score(model,X,y,cv=5).mean()
        X_train, X_test, y_train, y_test  = train_test_split(X,y,test_size=0.3,random_state=r)
        model.fit(X_train,y_train)
        pred = model.predict(X_test)
        curr_score = roc_auc_score(y_test,pred)
        if(curr_score >max_score):
            max_score = curr_score
            fin_r = r
    print('Max r value',fin_r)
    print('max Score', max_score)
    print('Cross_val_max_Score', cross_max_score)
    return fin_r,max_score,cross_max_score

# %%
from sklearn.model_selection import GridSearchCV
def Gridsearchvc(clf,params,cv,X,y):
    return_value=''
    clf = GridSearchCV(clf, params, cv=cv)
    clf.fit(X,y)
    print(clf.best_params_)
    return clf.best_params_

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
random_value, max_Score, cross_val_Score = max_score(model,X,y)

params={"C":[10,20,30],"tol":[0.0005,0.0015,0.0020]}
best_params = Gridsearchvc(model,params,5,X,y)
# Out:
# Max r value 89
# max Score 0.6267095073323447
# Cross_val_max_Score 0.8625880753317035
# {'C': 10, 'tol': 0.0005}

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
random_value, max_Score, cross_val_Score = max_score(model,X,y)

params={"criterion":['entropy','gini'],"max_leaf_nodes":[50,100,150]}
best_params = Gridsearchvc(model,params,5,X,y)
# Out:
# Max r value 86
# max Score 0.865542380476371
# Cross_val_max_Score 0.9150938044491268
# {'criterion': 'gini', 'max_leaf_nodes': 50}

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
random_value, max_Score, cross_val_Score = max_score(model,X,y)

params={"n_estimators":[10,100,500]}
best_params = Gridsearchvc(model,params,5,X,y)
# Out:
# Max r value 60
# max Score 0.8855616051623311
# Cross_val_max_Score 0.9552957755356555
# {'n_estimators': 500}

# %%
#using GradientBoosterAlgorithm 
from sklearn.ensemble import GradientBoostingClassifier
model=GradientBoostingClassifier()
random_value, max_Score, cross_val_Score = max_score(model,X,y)

params={
'n_estimators':[10,50,100],
'max_features':[0.5,0.11],
'learning_rate':[0.1,0.15],
'max_depth':[2,4],
'min_samples_leaf':[2,6],
'random_state':[50,70]
}

best_params = Gridsearchvc(model,params,5,X,y)
best_params
# Out:
# Max r value 48
# max Score 0.9078230606274589
# Cross_val_max_Score 0.9531963747855802
# {'learning_rate': 0.1, 'max_depth': 4, 'max_features': 0.5, 'min_samples_leaf': 2, 'n_estimators': 100, 'random_state': 50}
# {'learning_rate': 0.1,
#  'max_depth': 4,
#  'max_features': 0.5,
#  'min_samples_leaf': 2,
#  'n_estimators': 100,
#  'random_state': 50}

# %%
#using KNN 
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
random_value, max_Score, cross_val_Score = max_score(model,X,y)

params={"n_neighbors":range(1,100)}
best_params = Gridsearchvc(model,params,5,X,y)
best_params
# Out:
# Max r value 71
# max Score 0.726548963808307
# Cross_val_max_Score 0.8889906398152274
# {'n_neighbors': 5}
# {'n_neighbors': 5}
