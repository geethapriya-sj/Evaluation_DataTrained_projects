# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import glob

# %%
files = glob.glob('D://Data_Trained_Assignments//Project9_US_Corona//csse_covid_19_daily_reports_us//*.csv')
df = pd.concat([pd.read_csv(fp) for fp in files], ignore_index=True)
df
# Out:
#      Province_State Country_Region          Last_Update      Lat     Long_  \
# 0           Alabama             US  2020-04-12 23:18:15  32.3182  -86.9023
# 1            Alaska             US  2020-04-12 23:18:15  61.3707 -152.4044
# 2           Arizona             US  2020-04-12 23:18:15  33.7298 -111.4312
# 3          Arkansas             US  2020-04-12 23:18:15  34.9697  -92.3731
# 4        California             US  2020-04-12 23:18:15  36.1162 -119.6816
# ...             ...            ...                  ...      ...       ...
# 4073       Virginia             US  2020-06-21 04:33:37  37.7693  -78.1700
# 4074     Washington             US  2020-06-21 04:33:37  47.4009 -121.4905
# 4075  West Virginia             US  2020-06-21 04:33:37  38.4912  -80.9545
# 4076      Wisconsin             US  2020-06-21 04:33:37  44.2685  -89.6165
# 4077        Wyoming             US  2020-06-21 04:33:37  42.7560 -107.3025
#
#       Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  \
# ...

# %%
df.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                    float64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Province_State             0
# Country_Region             0
# Last_Update               19
# Lat                      158
# Long_                    158
# Confirmed                  0
# Deaths                     0
# Recovered               1103
# Active                    17
# FIPS                      19
# Incident_Rate            158
# People_Tested            158
# People_Hospitalized     1447
# Mortality_Rate            88
# UID                        0
# ISO3                       0
# Testing_Rate             158
# Hospitalization_Rate    1447
# dtype: int64

# %%
df.shape
# Out:
# (4078, 18)

# %%
df.describe(include='all')
# Out:
#         Province_State Country_Region          Last_Update          Lat  \
# count             4078           4078                 4059  3920.000000
# unique              59              1                   72          NaN
# top     North Carolina             US  2020-04-27 02:32:46          NaN
# freq                70           4078                   59          NaN
# mean               NaN            NaN                  NaN    36.840089
# std                NaN            NaN                  NaN    10.790768
# min                NaN            NaN                  NaN   -14.271000
# 25%                NaN            NaN                  NaN    34.594600
# 50%                NaN            NaN                  NaN    39.061850
# 75%                NaN            NaN                  NaN    42.361650
# max                NaN            NaN                  NaN    61.370700
#
#               Long_      Confirmed        Deaths      Recovered  \
# ...

# %% [raw]
# # we can see larger difference between 75 percentile and max for confirmed,deaths,recovered,active. ITs because we are including all states.
# # letd describe for few states

# %%
df[df['Province_State'] == 'New York'].describe()
# Out:
#                 Lat         Long_      Confirmed        Deaths     Recovered  \
# count  7.000000e+01  7.000000e+01      70.000000     70.000000     70.000000
# mean   4.216570e+01 -7.494810e+01  330233.057143  25903.600000  54093.828571
# std    7.156731e-15  4.294038e-14   54212.503143   5573.347846  17113.698014
# min    4.216570e+01 -7.494810e+01  189033.000000   9385.000000  23887.000000
# 25%    4.216570e+01 -7.494810e+01  300861.250000  23504.500000  53577.750000
# 50%    4.216570e+01 -7.494810e+01  349176.500000  28140.500000  61088.500000
# 75%    4.216570e+01 -7.494810e+01  373823.750000  30006.250000  66442.000000
# max    4.216570e+01 -7.494810e+01  387272.000000  31083.000000  69506.000000
#
#               Active  FIPS  Incident_Rate  People_Tested  People_Hospitalized  \
# count      70.000000  70.0      70.000000   7.000000e+01            70.000000
# mean   257193.628571  36.0    1799.862832   1.580189e+06         73998.614286
# ...

# %%
df[df['Province_State'] == 'New Jersey'].describe()
# Out:
#                 Lat   Long_      Confirmed        Deaths     Recovered  \
# count  7.000000e+01  70.000      70.000000     70.000000     54.000000
# mean   4.029890e+01 -74.521  135994.400000   9246.771429  22994.222222
# std    5.725385e-14   0.000   31100.703404   3159.740561   5480.585720
# min    4.029890e+01 -74.521   61850.000000   2350.000000  15642.000000
# 25%    4.029890e+01 -74.521  116936.750000   6885.250000  15642.000000
# 50%    4.029890e+01 -74.521  145796.500000  10312.000000  25146.500000
# 75%    4.029890e+01 -74.521  161937.250000  11852.750000  27778.250000
# max    4.029890e+01 -74.521  168834.000000  12924.000000  29318.000000
#
#               Active  FIPS  Incident_Rate  People_Tested  People_Hospitalized  \
# count      70.000000  70.0      70.000000   7.000000e+01            42.000000
# mean   109456.142857  34.0    1531.090868   5.506051e+05         13964.857143
# std     17655.404707   0.0     350.146793   3.433879e+05          5244.939157
# ...

# %% [raw]
# # as per describe per state , difference between 75 percent and max is minimum

# %%
df['Last_Update'] = pd.to_datetime(df['Last_Update']).dt.normalize()
df.head()
# Out:
#   Province_State Country_Region Last_Update      Lat     Long_  Confirmed  \
# 0        Alabama             US  2020-04-12  32.3182  -86.9023       3563
# 1         Alaska             US  2020-04-12  61.3707 -152.4044        272
# 2        Arizona             US  2020-04-12  33.7298 -111.4312       3542
# 3       Arkansas             US  2020-04-12  34.9697  -92.3731       1280
# 4     California             US  2020-04-12  36.1162 -119.6816      22795
#
#    Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      93        NaN   3470.0   1.0      75.988020        21583.0
# 1       8       66.0    264.0   2.0      45.504049         8038.0
# 2     115        NaN   3427.0   4.0      48.662422        42109.0
# 3      27      367.0   1253.0   5.0      49.439423        19722.0
# 4     640        NaN  22155.0   6.0      58.137726       190328.0
#
#    People_Hospitalized  Mortality_Rate       UID ISO3  Testing_Rate  \
# ...

# %%
df['Last_Update'].min()
# Out:
# Timestamp('2020-04-12 00:00:00')

# %%
df['Last_Update'].max()
# Out:
# Timestamp('2020-06-21 00:00:00')

# %%
df['Country_Region'].unique()
# Out:
# array(['US'], dtype=object)

# %%
df.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %%
df['ISO3'].unique()
# Out:
# array(['USA', 'GUM', 'PRI', 'ASM', 'MNP', 'VIR'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Province_State             0
# Country_Region             0
# Last_Update               19
# Lat                      158
# Long_                    158
# Confirmed                  0
# Deaths                     0
# Recovered               1103
# Active                    17
# FIPS                      19
# Incident_Rate            158
# People_Tested            158
# People_Hospitalized     1447
# Mortality_Rate            88
# UID                        0
# ISO3                       0
# Testing_Rate             158
# Hospitalization_Rate    1447
# dtype: int64

# %%
df.shape
# Out:
# (4078, 18)

# %%
df['Province_State'].value_counts()
# Out:
# North Carolina              70
# Missouri                    70
# Alaska                      70
# Washington                  70
# South Dakota                70
# Connecticut                 70
# Pennsylvania                70
# Idaho                       70
# Minnesota                   70
# Maryland                    70
# Wisconsin                   70
# California                  70
# Utah                        70
# Kansas                      70
# Mississippi                 70
# Texas                       70
# North Dakota                70
# Massachusetts               70
# Virgin Islands              70
# New Hampshire               70
# Tennessee                   70
# Oregon                      70
# Florida                     70
# Nebraska                    70
# Iowa                        70
# Northern Mariana Islands    70
# Hawaii                      70
# New York                    70
# Illinois                    70
# Delaware                    70
# ...

# %%
top_20_States_active = df.groupby('Province_State')['Active'].sum().sort_values(ascending=False).head(20).reset_index()
top_20_States_confirmed= df.groupby('Province_State')['Confirmed'].sum().sort_values(ascending=False).head(20).reset_index()
top_20_States_Deaths = df.groupby('Province_State')['Deaths'].sum().sort_values(ascending=False).head(20).reset_index()
top_20_States_Recovered = df.groupby('Province_State')['Recovered'].sum().sort_values(ascending=False).head(20).reset_index()

# %%
plt.figure(figsize=(50,10))
sns.barplot(x='Active',y='Province_State',data=top_20_States_active)

# %% [raw]
# #top 5 states are New york, California , New jersey,Illinois,Texas

# %%
plt.figure(figsize=(50,10))
sns.barplot(x='Confirmed',y='Province_State',data=top_20_States_confirmed)

# %%
plt.figure(figsize=(50,10))
sns.barplot(x='Deaths',y='Province_State',data=top_20_States_Deaths)

# %%
plt.figure(figsize=(50,10))
sns.barplot(x='Recovered',y='Province_State',data=top_20_States_Recovered)

# %%
df_Newyork = df[df['Province_State'] == 'New York']
df_Newyork = df_Newyork.groupby('Last_Update')['Recovered','Deaths','Active','Confirmed'].sum().reset_index()

# %%
df_NewJer = df[df['Province_State'] == 'New Jersey']
df_NewJer = df_NewJer.groupby('Last_Update')['Recovered','Deaths','Active','Confirmed'].sum().reset_index()

# %%
df_California = df[df['Province_State'] == 'California']
df_California = df_California.groupby('Last_Update')['Recovered','Deaths','Active','Confirmed'].sum().reset_index()

# %%
df_Indiana = df[df['Province_State'] == 'Indiana']
df_Indiana = df_Indiana.groupby('Last_Update')['Recovered','Deaths','Active','Confirmed'].sum().reset_index()

# %%
plt.figure(figsize=(15,10))
sns.pointplot(x=df_California.index,y=df_California.Confirmed,color='red')
sns.pointplot(x=df_NewJer.index,y=df_NewJer.Confirmed,color='Green')
sns.pointplot(x=df_Newyork.index,y=df_Newyork.Confirmed,color='yellow')
sns.pointplot(x=df_Indiana.index,y=df_Indiana.Confirmed,color='black')

# %%
plt.figure(figsize=(15,10))
sns.pointplot(x=df_California.index,y=df_California.Deaths,color='red')
sns.pointplot(x=df_NewJer.index,y=df_NewJer.Deaths,color='Green')
sns.pointplot(x=df_Newyork.index,y=df_Newyork.Deaths,color='yellow')
sns.pointplot(x=df_Indiana.index,y=df_Indiana.Deaths,color='black')
sns.pointplot(x=df_Indiana.index,y=df_Indiana.Deaths,color='black')

# %%
plt.figure(figsize=(100,5))
sns.barplot(x='Province_State',y='Testing_Rate',data=df.sort_values(by='Testing_Rate',ascending=False))

# %%
plt.figure(figsize=(60,5))
df.boxplot() #box plot show no outliers

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')

# %% [raw]
# #Confirmed,Deaths,Recoverd,Active,FIPS,Incident_rate,People_Tested,People_hospitalized are highly correlated

# %%
#pip install geopandas

# %%
df.head()
# Out:
#   Province_State Country_Region Last_Update      Lat     Long_  Confirmed  \
# 0        Alabama             US  2020-04-12  32.3182  -86.9023       3563
# 1         Alaska             US  2020-04-12  61.3707 -152.4044        272
# 2        Arizona             US  2020-04-12  33.7298 -111.4312       3542
# 3       Arkansas             US  2020-04-12  34.9697  -92.3731       1280
# 4     California             US  2020-04-12  36.1162 -119.6816      22795
#
#    Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      93        NaN   3470.0   1.0      75.988020        21583.0
# 1       8       66.0    264.0   2.0      45.504049         8038.0
# 2     115        NaN   3427.0   4.0      48.662422        42109.0
# 3      27      367.0   1253.0   5.0      49.439423        19722.0
# 4     640        NaN  22155.0   6.0      58.137726       190328.0
#
#    People_Hospitalized  Mortality_Rate       UID ISO3  Testing_Rate  \
# ...

# %%
plt.figure(figsize=(40,10))
total_cases = df.groupby('Last_Update')['Last_Update','Confirmed'].sum().reset_index()
ax = sns.pointplot(x='Last_Update',y='Confirmed',data=total_cases)

# %%
Total_Active = df.groupby('Province_State')['Active'].sum().sort_values(ascending=False).to_frame()
Total_Active.style.background_gradient(cmap='Blues_r')
# Out:
# <style  type="text/css" >
#     #T_07ab4d2e_b4ab_11ea_8a79_485f998011b0row0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_07ab4d2e_b4ab_11ea_8a79_485f998011b0row1_col0 {
#             background-color:  #60a7d2;
#             color:  #000000;
#         }    #T_07ab4d2e_b4ab_11ea_8a79_485f998011b0row2_col0 {
#             background-color:  #4090c5;
#             color:  #000000;
#         }    #T_07ab4d2e_b4ab_11ea_8a79_485f998011b0row3_col0 {
#             background-color:  #4090c5;
#             color:  #000000;
#         }    #T_07ab4d2e_b4ab_11ea_8a79_485f998011b0row4_col0 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_07ab4d2e_b4ab_11ea_8a79_485f998011b0row5_col0 {
#             background-color:  #1f6eb3;
#             color:  #f1f1f1;
#         }    #T_07ab4d2e_b4ab_11ea_8a79_485f998011b0row6_col0 {
#             background-color:  #1764ab;
#             color:  #f1f1f1;
# ...

# %%
df_confirmed,df_death,df_Recovered = df[['Last_Update','Confirmed']],df[['Last_Update','Deaths']],df[['Last_Update','Recovered']]

# %%
confirmed = df.groupby('Last_Update').sum()['Confirmed'].reset_index()
recovered = df.groupby('Last_Update').sum()['Recovered'].reset_index()
death = df.groupby('Last_Update').sum()['Deaths'].reset_index()

# %%
death
# Out:
#    Last_Update  Deaths
# 0   2020-04-12   22018
# 1   2020-04-13   23029
# 2   2020-04-14   26330
# 3   2020-04-15   28325
# 4   2020-04-16   32916
# ..         ...     ...
# 65  2020-06-17  116963
# 66  2020-06-18  117717
# 67  2020-06-19  118432
# 68  2020-06-20  119124
# 69  2020-06-21  119719
#
# [70 rows x 2 columns]

# %%
death[death['Deaths'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Last_Update, Deaths]
# Index: []

# %%
from fbprophet import Prophet

# %%
confirmed.columns=['ds','y']
confirmed['ds'] = pd.to_datetime(confirmed['ds'])

death.columns=['ds','y']
death['ds'] = pd.to_datetime(death['ds'])

recovered.columns=['ds','y']
recovered['ds'] = pd.to_datetime(recovered['ds'])

# %%
confirmed
# Out:
#            ds        y
# 0  2020-04-12   555262
# 1  2020-04-13   559600
# 2  2020-04-14   628689
# 3  2020-04-15   636350
# 4  2020-04-16   667801
# ..        ...      ...
# 65 2020-06-17  2137731
# 66 2020-06-18  2163290
# 67 2020-06-19  2191052
# 68 2020-06-20  2222579
# 69 2020-06-21  2255119
#
# [70 rows x 2 columns]

# %%
m_conformed = Prophet(interval_width=0.95)
m_conformed.fit(confirmed)
future_confirmed = m_conformed.make_future_dataframe(periods=7)
future_confirmed.tail()

m_death = Prophet(interval_width=0.95)
m_death.fit(death)
future_Death = m_death.make_future_dataframe(periods=7)
future_Death.tail()

m_recovered = Prophet(interval_width=0.95)
m_recovered.fit(recovered)
future_Recovered = m_recovered.make_future_dataframe(periods=7)
future_Recovered.tail()
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#            ds
# 72 2020-06-24
# 73 2020-06-25
# 74 2020-06-26
# 75 2020-06-27
# 76 2020-06-28

# %%
forecast_confirmed = m_conformed.predict(future_confirmed)

forecast_death = m_death.predict(future_Death)

forecast_recovery = m_recovered.predict(future_Recovered)

# %%
confirmed_forecast_plot =m.plot(forecast_confirmed)

# %%
confirmed_forecast_plot =m.plot_components(forecast_confirmed)

# %%
death_forecast_plot =m.plot(forecast_death)

# %%
death_forecast_plot =m.plot_components(forecast_death)

# %%
recovered_forecast_plot =m.plot(forecast_recovery)

# %%
recovered_forecast_plot =m.plot_components(forecast_recovery)
