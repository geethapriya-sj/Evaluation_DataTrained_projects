# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#read train and test data and concat both to one dataframe. we have the column source to indentify train and test
df_train = pd.read_excel('Data_Train.xlsx')
df_train['Source']="Train"
df_test= pd.read_excel('Data_Test.xlsx')
df_test['Source']="Test"
df = pd.concat([df_train,df_test],axis=0)
df
# Out:
#              CITY    COST                                       CUISINES  \
# 0           Thane  1200.0                    Malwani, Goan, North Indian
# 1         Chennai  1500.0                 Asian, Modern Indian, Japanese
# 2         Chennai   800.0     North Indian, Chinese, Biryani, Hyderabadi
# 3          Mumbai   800.0                               Tibetan, Chinese
# 4          Mumbai   300.0                                       Desserts
# ...           ...     ...                                            ...
# 4226    New Delhi     NaN                 North Indian, Mughlai, Chinese
# 4227    Bangalore     NaN  Biryani, North Indian, Sandwich, Salad, Wraps
# 4228    Faridabad     NaN                      Continental, North Indian
# 4229        Kochi     NaN                               Rolls, Beverages
# 4230  Bandra West     NaN                                        Mughlai
#
#               LOCALITY RATING  RESTAURANT_ID Source  \
# ...

# %%
 # reseting the index
df.reset_index(drop=True,inplace=True)

# %%
#Getting unique cities
df['CITY'].unique()
# Out:
# array(['Thane', 'Chennai', 'Mumbai', 'Bangalore', 'Gurgaon', 'Hyderabad',
#        'Kochi', 'Thane West', 'Andheri Lokhandwala', 'New Delhi',
#        'Andheri West', 'Malad East', '682036', 'Bangalor', 'Navi Mumbai',
#        'Bandra West', 'Delhi', 'Noida', 'Bangalore-560066',
#        'Secunderabad', nan, 'India', 'Madhuranagar', 'Chennai Teynampet',
#        'Faridabad', 'Chembur.', 'Maharashtra', 'opp gurudwara Shakurpur',
#        'Telagana Land Line:040-48507016', 'Ghaziabad', 'Karnataka',
#        'Kerala', 'Edappally', 'Kadavanthra', 'Ernakulam Circle kochi',
#        'Bengalore', 'Near Reliance Fresh', 'Kilpauk', 'Bengaluru',
#        'Kothaguda', 'Goregaon West', 'Banglore', 'Tamil Nadu', 'Kakkanad',
#        'Kochi Elamkulam', 'Outer Ring Road', 'Mulund East',
#        'Secunderabad main road near signal NMREC COLLEGE', 'Telangana',
#        'Ponnuruni Kochi', 'Gachibowli', 'Semmancheri',
#        '5th Main Teachers Colony Koramangala Block 1 Bangalore 560034',
# ...

# %%
#getting unique Cuisines
df['CUISINES'].unique()
# Out:
# array(['Malwani, Goan, North Indian', 'Asian, Modern Indian, Japanese',
#        'North Indian, Chinese, Biryani, Hyderabadi', ...,
#        'European, Mediterranean, Italian, Sushi',
#        'North Indian, Chinese, Kebab, Juices', 'Sindhi, Street Food'],
#       dtype=object)

# %%
#getting the unique locality
df['LOCALITY'].unique()
# Out:
# array(['Dombivali East', 'Ramapuram', 'Saligramam', ...,
#        'Off Carter Road', 'SRM Back Gate', 'Perry Cross Road'],
#       dtype=object)

# %%
#getting unique title
df['TITLE'].unique()
# Out:
# array(['CASUAL DINING', 'CASUAL DINING,BAR', 'QUICK BITES',
#        'DESSERT PARLOR', 'CAFÉ', 'MICROBREWERY',
#        'QUICK BITES,BEVERAGE SHOP', 'CASUAL DINING,IRANI CAFE',
#        'BAKERY,QUICK BITES', 'None', 'BAR,CASUAL DINING', 'BAR', 'PUB',
#        'BEVERAGE SHOP', 'FINE DINING', 'CAFÉ,QUICK BITES',
#        'BEVERAGE SHOP,DESSERT PARLOR', 'SWEET SHOP,QUICK BITES',
#        'DESSERT PARLOR,SWEET SHOP', 'BAKERY', 'BAKERY,DESSERT PARLOR',
#        'BAR,LOUNGE', 'FOOD COURT', 'LOUNGE',
#        'DESSERT PARLOR,BEVERAGE SHOP', 'LOUNGE,CASUAL DINING',
#        'FOOD TRUCK', 'QUICK BITES,FOOD COURT', 'SWEET SHOP',
#        'BEVERAGE SHOP,FOOD COURT', 'PUB,CASUAL DINING', 'MESS',
#        'MICROBREWERY,CASUAL DINING', 'CASUAL DINING,SWEET SHOP', 'KIOSK',
#        'QUICK BITES,KIOSK', 'CLUB', 'FINE DINING,BAR',
#        'DESSERT PARLOR,QUICK BITES', 'FOOD COURT,QUICK BITES',
#        'LOUNGE,CAFÉ', 'BAKERY,CONFECTIONERY', 'CASUAL DINING,CAFÉ',
# ...

# %%
#getting unique Cuisines
len(df['CUISINES'].unique())
# Out:
# 5183

# %%
#getting shape of train and test data
df_train.shape,df_test.shape
# Out:
# ((12690, 10), (4231, 9))

# %%
#Getting the unique title
len(df['TITLE'].unique())
# Out:
# 123

# %%
#top 5 rows in dataframe
df.head()
# Out:
#       CITY    COST                                    CUISINES  \
# 0    Thane  1200.0                 Malwani, Goan, North Indian
# 1  Chennai  1500.0              Asian, Modern Indian, Japanese
# 2  Chennai   800.0  North Indian, Chinese, Biryani, Hyderabadi
# 3   Mumbai   800.0                            Tibetan, Chinese
# 4   Mumbai   300.0                                    Desserts
#
#          LOCALITY RATING  RESTAURANT_ID Source  \
# 0  Dombivali East    3.6           9438  Train
# 1       Ramapuram    4.2          13198  Train
# 2      Saligramam    3.8          10915  Train
# 3     Bandra West    4.1           6346  Train
# 4     Lower Parel    3.8          15387  Train
#
#                                      TIME              TITLE      VOTES
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)      CASUAL DINING   49 votes
# 1                    6pm – 11pm (Mon-Sun)  CASUAL DINING,BAR   30 votes
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)      CASUAL DINING  221 votes
# ...

# %%
#getting the datatype of each column
df.dtypes
# Out:
# CITY              object
# COST             float64
# CUISINES          object
# LOCALITY          object
# RATING            object
# RESTAURANT_ID      int64
# Source            object
# TIME              object
# TITLE             object
# VOTES             object
# dtype: object

# %%
#Check for null column
df.isnull().sum()
# Out:
# CITY              147
# COST             4231
# CUISINES            0
# LOCALITY          128
# RATING              4
# RESTAURANT_ID       0
# Source              0
# TIME                0
# TITLE               0
# VOTES            1606
# dtype: int64

# %%
#check for null column in Train dataset
df[df.Source=='Train'].isnull().sum()
# Out:
# CITY              112
# COST                0
# CUISINES            0
# LOCALITY           98
# RATING              2
# RESTAURANT_ID       0
# Source              0
# TIME                0
# TITLE               0
# VOTES            1204
# dtype: int64

# %%
#check for null column in test dataset
df_train[df_train['VOTES'].isnull()]
# Out:
#                    TITLE  RESTAURANT_ID  \
# 13         CASUAL DINING           4319
# 62           QUICK BITES           7841
# 69                  None          11096
# 85           QUICK BITES          12657
# 111        CASUAL DINING           7095
# ...                  ...            ...
# 12630      CASUAL DINING           9959
# 12641      CASUAL DINING           8312
# 12646        QUICK BITES           6050
# 12658               None           9384
# 12660  CASUAL DINING,BAR           1439
#
#                                             CUISINES  \
# 13                                      South Indian
# 62                           North Indian, Beverages
# 69                                  Pizza, Fast Food
# 85                        North Indian, South Indian
# 111               Gujarati, Rajasthani, North Indian
# ...                                              ...
# 12630                       Tex-Mex, Italian, Coffee
# ...

# %%
#Fill votes column with zero for nan values
df['VOTES'].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# CITY              147
# COST             4231
# CUISINES            0
# LOCALITY          128
# RATING              4
# RESTAURANT_ID       0
# Source              0
# TIME                0
# TITLE               0
# VOTES               0
# dtype: int64

# %%
#check for rating null rows
df[df['RATING'].isnull()]
# Out:
#             CITY   COST                             CUISINES       LOCALITY  \
# 204        Kochi  200.0                               Bakery   Marine Drive
# 421    Hyderabad  350.0                      Cafe, Fast Food  Banjara Hills
# 14725      Kochi    NaN                      Kerala, Arabian       Kakkanad
# 15448      Kochi    NaN  Chinese, North Indian, South Indian   Tripunithura
#
#       RATING  RESTAURANT_ID Source           TIME        TITLE VOTES
# 204      NaN          15062  Train  Not Available       BAKERY     0
# 421      NaN          14127  Train  Not Available         CAFÉ     0
# 14725    NaN           2776   Test  Not Available  QUICK BITES     0
# 15448    NaN          11301   Test  Not Available         None     0

# %%
# getting the count of each value in rating
df['RATING'].value_counts()
# Out:
# 3.9    1643
# 3.8    1604
# 4.0    1498
# 3.7    1437
# 3.6    1261
# 4.1    1217
# 3.5     988
# 4.2     968
# NEW     930
# 3.4     777
# 4.3     740
# -       672
# 3.3     485
# 4.4     484
# 3.2     349
# 4.5     274
# 3.1     263
# 2.9     242
# 3.0     229
# 2.8     191
# 4.6     184
# 2.7     129
# 4.7      90
# 2.6      85
# 2.5      51
# 4.8      49
# 4.9      28
# 2.4      24
# 2.3      15
# 2.2       4
# 2.1       4
# 2.0       2
# Name: RATING, dtype: int64

# %%
#We can see NEW and - in Ratings, Lets handle these values
df['RATING'].replace("NEW",0,inplace=True)
df['RATING'].replace("-",0,inplace=True)
df['RATING'].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# CITY              147
# COST             4231
# CUISINES            0
# LOCALITY          128
# RATING              0
# RESTAURANT_ID       0
# Source              0
# TIME                0
# TITLE               0
# VOTES               0
# dtype: int64

# %%
#check for datatypes in dataframe
df.dtypes
# Out:
# CITY              object
# COST             float64
# CUISINES          object
# LOCALITY          object
# RATING            object
# RESTAURANT_ID      int64
# Source            object
# TIME              object
# TITLE             object
# VOTES             object
# dtype: object

# %%
df['VOTES'].value_counts()
# Out:
# 0             1606
# 44 votes        92
# 22 votes        88
# 6 votes         87
# 29 votes        83
#               ...
# 3367 votes       1
# 2132 votes       1
# 1687 votes       1
# 3378 votes       1
# 6163 votes       1
# Name: VOTES, Length: 2076, dtype: int64

# %%
df['VOTES'] = df['VOTES'].str.split(" ").str[0]
df.head()
# Out:
#       CITY    COST                                    CUISINES  \
# 0    Thane  1200.0                 Malwani, Goan, North Indian
# 1  Chennai  1500.0              Asian, Modern Indian, Japanese
# 2  Chennai   800.0  North Indian, Chinese, Biryani, Hyderabadi
# 3   Mumbai   800.0                            Tibetan, Chinese
# 4   Mumbai   300.0                                    Desserts
#
#          LOCALITY RATING  RESTAURANT_ID Source  \
# 0  Dombivali East    3.6           9438  Train
# 1       Ramapuram    4.2          13198  Train
# 2      Saligramam    3.8          10915  Train
# 3     Bandra West    4.1           6346  Train
# 4     Lower Parel    3.8          15387  Train
#
#                                      TIME              TITLE VOTES
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)      CASUAL DINING    49
# 1                    6pm – 11pm (Mon-Sun)  CASUAL DINING,BAR    30
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)      CASUAL DINING   221
# ...

# %%
df['VOTES'] = df['VOTES'].astype(float)
df['RATING'] = df['RATING'].astype(float)

# %%
df.head()
# Out:
#       CITY    COST                                    CUISINES  \
# 0    Thane  1200.0                 Malwani, Goan, North Indian
# 1  Chennai  1500.0              Asian, Modern Indian, Japanese
# 2  Chennai   800.0  North Indian, Chinese, Biryani, Hyderabadi
# 3   Mumbai   800.0                            Tibetan, Chinese
# 4   Mumbai   300.0                                    Desserts
#
#          LOCALITY  RATING  RESTAURANT_ID Source  \
# 0  Dombivali East     3.6           9438  Train
# 1       Ramapuram     4.2          13198  Train
# 2      Saligramam     3.8          10915  Train
# 3     Bandra West     4.1           6346  Train
# 4     Lower Parel     3.8          15387  Train
#
#                                      TIME              TITLE  VOTES
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)      CASUAL DINING   49.0
# 1                    6pm – 11pm (Mon-Sun)  CASUAL DINING,BAR   30.0
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)      CASUAL DINING  221.0
# ...

# %%
df_train.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              112
# LOCALITY           98
# RATING              2
# VOTES            1204
# COST                0
# Source              0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# TITLE              0
# RESTAURANT_ID      0
# CUISINES           0
# TIME               0
# CITY              35
# LOCALITY          30
# RATING             2
# VOTES            402
# Source             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CITY              147
# COST             4231
# CUISINES            0
# LOCALITY          128
# RATING              0
# RESTAURANT_ID       0
# Source              0
# TIME                0
# TITLE               0
# VOTES            1606
# dtype: int64

# %%
df[(df['CITY'].isnull()) & (df['LOCALITY'].notnull())]
# Out:
#       CITY    COST                                           CUISINES  \
# 246    NaN   300.0                                            Biryani
# 817    NaN  1200.0  Thai, Chinese, Continental, North Indian, Italian
# 5149   NaN   400.0                     Beverages, Ice Cream, Desserts
# 5297   NaN  1000.0                                        Continental
# 6397   NaN   950.0  Cafe, American, Asian, Bakery, Biryani, Chines...
# 6451   NaN   400.0                                             Bakery
# 8456   NaN   150.0                               Fast Food, Beverages
# 8735   NaN   400.0                                    Chinese, Burger
# 9121   NaN  1500.0  Finger Food, American, Continental, Burger, Pizza
# 9268   NaN   200.0                                           Lebanese
# 10200  NaN   300.0  North Indian, Chinese, Sandwich, Street Food, ...
# 10704  NaN   650.0                             Continental, Fast Food
# ...

# %%
# Those Locality containing 400013 is mumabi
df.loc[df[df['LOCALITY'].str.contains('400013') == True].index,'CITY'] = 'Mumbai'

# %%
df.loc[df[(df['CITY'].isnull()) & (df['LOCALITY'].notnull())].index,'CITY'] = df['LOCALITY']

# %%
df[(df['CITY'].isnull()) & (df['LOCALITY'].notnull())]
# Out:
# Empty DataFrame
# Columns: [CITY, COST, CUISINES, LOCALITY, RATING, RESTAURANT_ID, Source, TIME, TITLE, VOTES]
# Index: []

# %%
df[(df['CITY'].isnull())]
# Out:
#       CITY   COST                                          CUISINES LOCALITY  \
# 129    NaN  500.0  North Indian, South Indian, Chinese, Continental      NaN
# 411    NaN  600.0   North Indian, Chinese, Pizza, Burger, Fast Food      NaN
# 466    NaN  200.0                                      North Indian      NaN
# 481    NaN  250.0                                       Street Food      NaN
# 534    NaN  600.0                       Healthy Food, Salad, Juices      NaN
# ...    ...    ...                                               ...      ...
# 16246  NaN    NaN                Street Food, North Indian, Chinese      NaN
# 16250  NaN    NaN                                  Biryani, Mughlai      NaN
# 16313  NaN    NaN      North Indian, South Indian, Chinese, Biryani      NaN
# 16803  NaN    NaN               Fast Food, Italian, Pizza, Sandwich      NaN
# 16815  NaN    NaN                             Chinese, North Indian      NaN
#
#        RATING  RESTAURANT_ID Source  \
# ...

# %%
#For all remaining rows ,we can update both city and locality as missing
df.loc[df[(df['CITY'].isnull())].index,['LOCALITY','CITY']] = ['Missing','Missing']

# %%
df.isnull().sum()
# Out:
# CITY                0
# COST             4231
# CUISINES            0
# LOCALITY            1
# RATING              0
# RESTAURANT_ID       0
# Source              0
# TIME                0
# TITLE               0
# VOTES            1606
# dtype: int64

# %%
df[df['LOCALITY'].isnull()]
# Out:
#                             CITY   COST CUISINES LOCALITY  RATING  \
# 12181  Kadubesanahalli Bangalore  300.0    Asian      NaN     0.0
#
#        RESTAURANT_ID Source                                             TIME  \
# 12181           3861  Train  11am – 11pm (Mon, Tue, Thu, Sun), 11am – 3pm...
#
#       TITLE  VOTES
# 12181  None    NaN

# %%
df.loc[df[df['LOCALITY'].isnull()].index,'LOCALITY'] = 'Kadubesanahalli'

# %%
df.isnull().sum()
# Out:
# CITY                0
# COST             4231
# CUISINES            0
# LOCALITY            0
# RATING              0
# RESTAURANT_ID       0
# Source              0
# TIME                0
# TITLE               0
# VOTES            1606
# dtype: int64

# %%
df[df['VOTES'].isnull()]
# Out:
#             CITY   COST                            CUISINES       LOCALITY  \
# 13         Kochi  400.0                        South Indian      Edappally
# 62         Kochi  200.0             North Indian, Beverages    Kalamassery
# 69     New Delhi  200.0                    Pizza, Fast Food        Kalkaji
# 85     Bangalore  300.0          North Indian, South Indian    Vijay Nagar
# 111       Mumbai  800.0  Gujarati, Rajasthani, North Indian  Borivali West
# ...          ...    ...                                 ...            ...
# 16873      Noida    NaN                  Cafe, North Indian      Sector 63
# 16875  New Delhi    NaN                           Fast Food  Shalimar Bagh
# 16888  Bangalore    NaN                         Continental    Indiranagar
# 16913     Mumbai    NaN                 Sindhi, Street Food    Lower Parel
# 16919      Kochi    NaN                    Rolls, Beverages          Kochi
#
#        RATING  RESTAURANT_ID Source  \
# ...

# %%
df['VOTES'].fillna(0,inplace=True)

# %%
df[df['VOTES'].isnull()]
# Out:
# Empty DataFrame
# Columns: [CITY, COST, CUISINES, LOCALITY, RATING, RESTAURANT_ID, Source, TIME, TITLE, VOTES]
# Index: []

# %%
df.drop(columns=['RESTAURANT_ID','TIME'],inplace=True)

# %%
df
# Out:
#               CITY    COST                                       CUISINES  \
# 0            Thane  1200.0                    Malwani, Goan, North Indian
# 1          Chennai  1500.0                 Asian, Modern Indian, Japanese
# 2          Chennai   800.0     North Indian, Chinese, Biryani, Hyderabadi
# 3           Mumbai   800.0                               Tibetan, Chinese
# 4           Mumbai   300.0                                       Desserts
# ...            ...     ...                                            ...
# 16916    New Delhi     NaN                 North Indian, Mughlai, Chinese
# 16917    Bangalore     NaN  Biryani, North Indian, Sandwich, Salad, Wraps
# 16918    Faridabad     NaN                      Continental, North Indian
# 16919        Kochi     NaN                               Rolls, Beverages
# 16920  Bandra West     NaN                                        Mughlai
#
#                LOCALITY  RATING Source              TITLE  VOTES
# ...

# %%
#Now we will divide the CUISINES column into multiple columns
#First we will find maximum number of cuisines resutarnt are serving
max_cuisines=0
for i in range(len(df["CUISINES"])):
    temp=len(df["CUISINES"].iloc[i].split(","))
    if temp>max_cuisines:
        max_cuisines=temp
print("Max number of cuisines serverd are :{}".format(max_cuisines))
# Out:
# Max number of cuisines serverd are :8

# %%
len(df["CUISINES"])
# Out:
# 16921

# %%
c1=list()
c2=list()
c3=list()
c4=list()
c5=list()
c6=list()
c7=list()
c8=list()
for i in range(len(df["CUISINES"])):
    temp=df["CUISINES"].iloc[i].split(",")
    try :
        c1.append(temp[0].strip().upper())
    except :
        c1.append('NONE')
    try :
        c2.append(temp[1].strip().upper())
    except :
        c2.append('NONE')
    try :
        c3.append(temp[2].strip().upper())
    except :
        c3.append('NONE')
    try :
        c4.append(temp[3].strip().upper())
    except :
        c4.append('NONE')
    try :
        c5.append(temp[4].strip().upper())
    except :
        c5.append('NONE')
    try :
        c6.append(temp[5].strip().upper())
    except :
        c6.append('NONE')
    try :
        c7.append(temp[6].strip().upper())
    except :
        c7.append('NONE')
    try :
        c8.append(temp[7].strip().upper())
    except :
        c8.append('NONE')

# %%
df["c1"]=c1
df["c2"]=c2
df["c3"]=c3
df["c4"]=c4
df["c5"]=c5
df["c6"]=c6
df["c7"]=c7
df["c8"]=c8

# %%
#Now we will divide the "TITLE" column into multiple columns
#First we will find maximum number of TITLE resutarnt having
max_titles=-1
for i in range(len(df["TITLE"])):
    temp=len(df["TITLE"].iloc[i].split(","))
    if temp>max_titles:
        max_titles=temp
print("Max number of titles are :{}".format(max_titles))
# Out:
# Max number of titles are :2

# %%
t1=list()
t2=list()
for i in range(len(df["TITLE"])):
    temp=df["TITLE"].iloc[i].split(",")
    try :
        t1.append(temp[0].strip().upper())
    except :
        t1.append('NONE')
    try :
        t2.append(temp[1].strip().upper())
    except :
        t2.append('NONE')

# %%
df["t1"]=t1
df["t2"]=t2

# %%
df
# Out:
#               CITY    COST                                       CUISINES  \
# 0            Thane  1200.0                    Malwani, Goan, North Indian
# 1          Chennai  1500.0                 Asian, Modern Indian, Japanese
# 2          Chennai   800.0     North Indian, Chinese, Biryani, Hyderabadi
# 3           Mumbai   800.0                               Tibetan, Chinese
# 4           Mumbai   300.0                                       Desserts
# ...            ...     ...                                            ...
# 16916    New Delhi     NaN                 North Indian, Mughlai, Chinese
# 16917    Bangalore     NaN  Biryani, North Indian, Sandwich, Salad, Wraps
# 16918    Faridabad     NaN                      Continental, North Indian
# 16919        Kochi     NaN                               Rolls, Beverages
# 16920  Bandra West     NaN                                        Mughlai
#
#                LOCALITY  RATING Source              TITLE  VOTES  \
# ...

# %%
df.drop(columns=['CUISINES','TITLE'],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
for col in df.columns:
    if df[col].dtype=="object":
        df[col]=LabelEncoder().fit_transform(df[col])

# %%
df_train_final = df[df['Source'] ==1].reset_index(drop=True)
df_test_final = df[df['Source'] == 0].reset_index(drop=True)

# %%
#Dropping the source column
df_train_final.drop(columns=["Source"],inplace=True)
df_test_final.drop(columns=["Source"],inplace=True)

# %%
X = df_train_final.drop(columns=['COST'])
y = df_train_final['COST']

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_squared_log_error,r2_score
def getscore_metrics(prediction,actual):
    print("mean_squared_error:",mean_squared_error(prediction,actual))
    print("mean_absolute_error:",mean_absolute_error(prediction,actual))
    print("mean_squared_log_error:",mean_squared_log_error(prediction,actual))
    print("r2_score:",r2_score(prediction,actual))

# %%
def parsemodel(model,X,y,X_test,y_test):
    model.fit(X,y)
    pred = model.predict(X_test)
    model.score(X_test,y_test)
    getscore_metrics(pred,y_test)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y,random_state = 50,test_size=0.20)

# %%
#Lets use decision tree
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor(random_state=71)
print("cross_val_score:",cross_val_score(dtr,x_train,y_train,cv=5).mean())#(LogisticRegression,X,y
parsemodel(dtr,x_train,y_train,x_test,y_test)
# Out:
# cross_val_score: 0.4185373293599472
# mean_squared_error: 247867.44887706856
# mean_absolute_error: 262.1562253743105
# mean_squared_log_error: 0.2893586111989459
# r2_score: 0.4993842601427616

# %%
from sklearn.ensemble import RandomForestRegressor
rDM = RandomForestRegressor(n_estimators = 500)
print("cross_val_score:",cross_val_score(rDM,x_train,y_train,cv=5).mean())#(LogisticRegression,X,y
parsemodel(rDM,x_train,y_train,x_test,y_test)
# Out:
# cross_val_score: 0.6997416468809468
# mean_squared_error: 104830.64129210556
# mean_absolute_error: 192.23251924430184
# mean_squared_log_error: 0.16073592610410437
# r2_score: 0.6926946200147294

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
print("cross_val_score:",cross_val_score(SVC(),x_train,y_train,cv=5).mean())#(LogisticRegression,X,y
parsemodel(SVC(),x_train,y_train,x_test,y_test)
# Out:
# cross_val_score: 0.1414499882365211
# mean_squared_error: 391161.1903073286
# mean_absolute_error: 341.31954294720254
# mean_squared_log_error: 0.51464492926484
# r2_score: -6.245526431869329

# %%
from sklearn.neighbors import KNeighborsRegressor
print("cross_val_score:",cross_val_score(KNeighborsRegressor(),x_train,y_train,cv=5).mean())#(LogisticRegression,X,y
parsemodel(KNeighborsRegressor(),x_train,y_train,x_test,y_test)
# Out:
# cross_val_score: 0.06461893067997349
# mean_squared_error: 331528.23208825843
# mean_absolute_error: 351.70260047281323
# mean_squared_log_error: 0.45878708527869483
# r2_score: -1.2118989312473478

# %%
from sklearn.ensemble import AdaBoostRegressor
print("cross_val_score:",cross_val_score(AdaBoostRegressor(),x_train,y_train,cv=5).mean())#(LogisticRegression,X,y
parsemodel(AdaBoostRegressor(),x_train,y_train,x_test,y_test)
# Out:
# cross_val_score: -0.41668075930655063
# mean_squared_error: 594572.1141287392
# mean_absolute_error: 658.9379161072516
# mean_squared_log_error: 1.0384199642813756
# r2_score: -0.8621456819105597

# %%
from sklearn.ensemble import GradientBoostingRegressor
print("cross_val_score:",cross_val_score(GradientBoostingRegressor(),x_train,y_train,cv=5).mean())#(LogisticRegression,X,y
parsemodel(GradientBoostingRegressor(),x_train,y_train,x_test,y_test)
# Out:
# cross_val_score: 0.6875833972553173
# mean_squared_error: 103431.0437663794
# mean_absolute_error: 198.52823338129764
# mean_squared_log_error: 0.18370892147922807
# r2_score: 0.5732687382785724

# %%
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
lg = lgb.LGBMRegressor(silent=False)
param_dist = {"max_depth": [25,50, 75],
              "learning_rate" : [0.01,0.05,0.1],
              "num_leaves": [300,900,1200],
              "n_estimators": [200]
             }
grid_search = GridSearchCV(lg, n_jobs=-1, param_grid=param_dist, cv = 5, scoring="r2")
grid_search.fit(x_train,y_train)
grid_search.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 25,
#  'n_estimators': 200,
#  'num_leaves': 300}

# %%
params={'learning_rate': 0.05,'max_depth': 25,'n_estimators': 200,'num_leaves': 300}
cate_features_name=['CITY', 'LOCALITY', 'c1', 'c2', 'c3', 'c4', 'c5','c6', 'c7', 'c8', 't1', 't2']
d_train = lgb.Dataset(x_train, label=y_train)
lgb_model = lgb.train(params, d_train, categorical_feature = cate_features_name)
y_pred = lgb_model.predict(x_test)

# %%
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# RMSE is:  297.99368678246844
# r2_score is:  0.7541945002721362

# %%
cost_pred=lgb_model.predict(df_test_final.drop(columns=['COST']))

# %%
cost_pred=pd.DataFrame(cost_pred,columns=["COST"])

# %%
cost_pred.to_csv("FoodCost_Predictions.csv",index=False)
